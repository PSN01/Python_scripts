# %%
import pandas as pd
import numpy as np
def create_one_hot(index,aa_count):
    a=[]
    for i in range(0,aa_count):
        a.append(str(0))
    a[index]=str(1)
    return a
k=open('list.txt','r')
s=open('n5n1.txt','a')
t=k.readlines()
y=list(t)
r=[]
j=[]
for w in y:
    w.replace("\n", "")
    r.append(int(w))
r.sort()
print(r)
count=0
with open('5ncc.txt','r') as f:
    for line in f.readlines():
        aa_count=len(line)-1
        if len(line)<r[count]:
            print('error index value > length of line')
        elif (r[count]<=0):
             print('error index value <=0 ')
        else:
            ntxt=line[0:r[count]-1]+'A'+line[r[count]:]
            print(ntxt)
            s.write(ntxt)
            count+=1
s.close()
# Out:
# [63, 64, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 79, 93, 95, 96, 97, 98, 99, 100, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 165, 166, 167, 170, 172, 173, 176, 191, 192, 204, 205, 206, 207, 208, 213, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 355, 356, 358, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 455, 467, 471, 473, 474, 492, 493, 497, 506, 509, 510, 511, 512, 513, 514, 515, 516, 517, 556, 557, 558, 559, 560, 561, 562, 563, 564, 585]
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
